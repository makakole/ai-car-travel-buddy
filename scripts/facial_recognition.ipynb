# %%
import cv2
import matplotlib.pyplot as plt
import time
import os
import numpy as np
# %matplotlib inline

# %%
def convertToRGB(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
haar_face_cascade = cv2.CascadeClassifier('../data/haarcascade_frontalface_alt.xml')

# %%
def detect_faces(f_cascade, colored_img, scaleFactor = 1.2):
    #making a copy of image passed, so that passed image is not changed
    img_copy = colored_img.copy()
    #convert the test image to gray image as opencv face detector expects gray images
    gray = cv2.cvtColor(img_copy, cv2.COLOR_BGR2GRAY)       
    #let's detect multiscale (some images may be closer to camera than others) images
    faces = f_cascade.detectMultiScale(gray, scaleFactor=scaleFactor, minNeighbors=5);   
    #go over list of faces and draw them as rectangles on original colored img
    for (x, y, w, h) in faces:
        cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)
    return img_copy

# %%
test2 = cv2.imread('../data/img2.jpg')

# %%
faces_detected = detect_faces(haar_face_cascade, test2)

# %%
plt.imshow(convertToRGB(faces_detected))

# %%
bp_face_cascade = cv2.CascadeClassifier('../data/lbpcascade_frontalface.xml')

# %%
test1 = cv2.imread('../data/img1.jpg')

# %%
faces_detected2 = detect_faces(bp_face_cascade, test1, 1.1)

# %%
plt.imshow(convertToRGB(faces_detected2))
